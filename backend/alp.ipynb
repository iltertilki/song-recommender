# %%
import os
import librosa
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
import logging

# Setup basic configuration for logging
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

def extract_features(file_path):
    try:
        y, sr = librosa.load(file_path)
        tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
        chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr).mean()
        rmse = librosa.feature.rms(y=y).mean()
        spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr).mean()
        spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr).mean()
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr).mean()
        zero_crossing_rate = librosa.feature.zero_crossing_rate(y).mean()
        mfcc = librosa.feature.mfcc(y=y, sr=sr).mean(axis=1)
        features = {'tempo': tempo, 'chroma_stft': chroma_stft, 'rmse': rmse, 'spectral_centroid': spectral_centroid,
                    'spectral_bandwidth': spectral_bandwidth, 'rolloff': rolloff, 'zero_crossing_rate': zero_crossing_rate}
        for i, coef in enumerate(mfcc):
            features[f'mfcc_{i+1}'] = coef
        return features
    except Exception as e:
        logging.error(f"Failed to process {file_path}: {e}")
        return None  # Return None or a default dictionary if an error occurs

def process_directory(directory):
    features_list = []
    for file_name in os.listdir(directory):
        if file_name.endswith('.mp3'):
            file_path = os.path.join(directory, file_name)
            features = extract_features(file_path)
            if features is not None:  # Only append if extraction was successful
                features['song'] = file_name
                features_list.append(features)
    print(f"Completed processing directory: {directory}")
    return features_list

def main():
    root_dir = r'D:\MMC-Project\song-recommender\backend\data'
    directories = [os.path.join(root_dir, f"{i:03d}") for i in range(156) if os.path.exists(os.path.join(root_dir, f"{i:03d}"))]
    with ThreadPoolExecutor(max_workers=52) as executor:
        results = executor.map(process_directory, directories)
    all_features = [feature for result in results for feature in result if feature is not None]
    df = pd.DataFrame(all_features)
    df.to_csv('song_features.csv', index=False)
    print("All directories processed and data saved to CSV.")

if __name__ == "__main__":
    main()
# Out:
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\002
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\008
# c:\Users\alpgi\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\034
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\005
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\031
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\020
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\023
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\015
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\050
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\018
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\009
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\022
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\041
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\028
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\030
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\016
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\035
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\037
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\017
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\039
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\033
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\021
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\046
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\019
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\025
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\049
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\007
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\032
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\027
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\045
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\013
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\077
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\029
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\053
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\048
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\051
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\044
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\065
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\047
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\036
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\061
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\003
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\058
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\042
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\078
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\040
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\079
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\024
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\026
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\076
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\001
# C:\Users\alpgi\AppData\Local\Temp\ipykernel_9568\3559425857.py:12: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file_path)
# c:\Users\alpgi\AppData\Local\Programs\Python\Python312\Lib\site-packages\librosa\core\audio.py:183: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# 2024-05-10 02:04:54,499 - ERROR - Failed to process D:\MMC-Project\song-recommender\backend\data\099\099134.mp3:
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\070
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\000
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\014
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\066
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\102
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\010
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\012
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\101
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\060
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\004
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\063
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\103
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\006
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\057
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\083
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\082
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\074
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\100
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\095
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\062
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\043
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\059
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\052
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\088
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\090
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\067
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\054
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\068
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\038
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\080
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\089
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\094
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\081
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\011
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\093
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\055
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\104
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\056
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\072
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\084
# 2024-05-10 02:11:46,217 - ERROR - Failed to process D:\MMC-Project\song-recommender\backend\data\098\098565.mp3:
# 2024-05-10 02:11:46,296 - ERROR - Failed to process D:\MMC-Project\song-recommender\backend\data\098\098567.mp3:
# 2024-05-10 02:11:46,401 - ERROR - Failed to process D:\MMC-Project\song-recommender\backend\data\098\098569.mp3:
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\106
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\071
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\086
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\096
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\099
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\069
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\092
# 2024-05-10 02:14:06,555 - ERROR - Failed to process D:\MMC-Project\song-recommender\backend\data\133\133297.mp3:
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\087
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\105
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\151
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\073
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\097
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\064
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\155
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\136
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\153
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\117
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\154
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\147
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\109
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\112
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\150
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\152
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\135
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\085
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\091
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\128
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\075
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\119
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\146
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\098
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\140
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\143
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\118
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\139
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\124
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\132
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\115
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\111
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\149
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\138
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\137
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\121
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\130
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\141
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\116
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\144
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\107
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\123
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\110
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\134
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\120
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\125
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\113
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\142
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\131
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\145
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\129
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\148
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\122
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\133
# 2024-05-10 02:23:04,801 - ERROR - Failed to process D:\MMC-Project\song-recommender\backend\data\108\108925.mp3:
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\114
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\108
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\127
# Completed processing directory: D:\MMC-Project\song-recommender\backend\data\126
# All directories processed and data saved to CSV.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np

# Load the data
df = pd.read_csv('song_features.csv')

# Separate numeric and non-numeric data
numeric_cols = df.select_dtypes(include=[np.number]).columns
non_numeric_cols = df.columns.difference(numeric_cols)

# Check for missing values in numeric columns and fill them with the column mean
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# Normalize features in numeric columns only
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# Now df is properly preprocessed, with the 'song' column unchanged

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import NearestNeighbors

# Split the data
X = df.drop('song', axis=1)
y = df['song']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Train the model
model = NearestNeighbors(n_neighbors=5, algorithm='ball_tree')
model.fit(X_train)
# Out:
# NearestNeighbors(algorithm='ball_tree')

# %%
from joblib import dump

dump(model, 'nearest_neighbors_model.joblib')
# Out:
# ['nearest_neighbors_model.joblib']

# %%
# Find nearest neighbors for a test set
distances, indices = model.kneighbors(X_test)

# %%
def recommend(song_index, n_recommendations=5):
    #given song
    print(f"Recommendations for {y.iloc[song_index]}")
    distances, indices = model.kneighbors(X.loc[song_index:song_index])
    return y.iloc[indices[0]]

# Recommend songs similar to the first song in the test set
recommendations = recommend(12)
print(recommendations)
# Out:
# Recommendations for 000203.mp3
# 1264    032325.mp3
# 2055    051113.mp3
# 3649    081792.mp3
# 54      000853.mp3
# 6205    125160.mp3
# Name: song, dtype: object
